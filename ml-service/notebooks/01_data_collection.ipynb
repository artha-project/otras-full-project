# %%
import pandas as pd
import numpy as np
from pathlib import Path
import random

BASE_DIR = Path("../").resolve()
DATA_DIR = BASE_DIR / "data"
DATA_DIR.mkdir(exist_ok=True)

print("Data directory:", DATA_DIR)
# Out:
# Data directory: E:\OTRAS-PLATFORM\otras-platform\ml-service\data

# %%
FEATURE_COLUMNS = [
    "aptitude_score",
    "subject_score",
    "time_management_score",
    "mock_average_score",
    "consistency_score"
]

TARGET_COLUMN = "readiness_score"

# %%
def generate_student_sample():
    aptitude = random.uniform(30, 95)
    subject = random.uniform(25, 95)
    time_mgmt = random.uniform(20, 95)
    mock_avg = random.uniform(20, 95)
    consistency = random.uniform(20, 95)

    # Deterministic readiness formula (baseline truth)
    readiness = (
        0.25 * aptitude +
        0.25 * subject +
        0.2 * time_mgmt +
        0.2 * mock_avg +
        0.1 * consistency
    )

    return [
        aptitude,
        subject,
        time_mgmt,
        mock_avg,
        consistency,
        readiness
    ]

# %%
data = [generate_student_sample() for _ in range(5000)]

df = pd.DataFrame(
    data,
    columns=FEATURE_COLUMNS + [TARGET_COLUMN]
)

df.head()
# Out:
#    aptitude_score  subject_score  time_management_score  mock_average_score  \
# 0       55.684743      41.260901              25.012146           34.637652
# 1       75.468742      89.229213              77.824238           23.073926
# 2       48.693446      84.517416              47.995144           66.870604
# 3       94.136302      52.295537              94.017249           94.642967
# 4       66.132522      65.180892              21.649843           86.697300
#
#    consistency_score  readiness_score
# 0          52.245455        41.390916
# 1          25.683113        63.922433
# 2          25.155269        58.791392
# 3          41.441999        78.484203
# 4          75.433893        62.041172

# %%
print("Dataset shape:", df.shape)
print(df.describe())
print("Missing values:", df.isnull().sum())
# Out:
# Dataset shape: (5000, 6)
#        aptitude_score  subject_score  time_management_score  \
# count     5000.000000    5000.000000            5000.000000
# mean        62.315489      59.866491              57.540936
# std         18.878186      20.215940              21.652951
# min         30.018215      25.002176              20.002746
# 25%         45.822072      42.457413              38.460051
# 50%         62.230253      59.663187              58.032281
# 75%         79.058015      77.854055              76.374016
# max         94.974094      94.937634              94.995025
#
#        mock_average_score  consistency_score  readiness_score
# count         5000.000000        5000.000000      5000.000000
# mean            57.516082          57.412545        59.298153
# std             21.308833          21.583009         9.365245
# min             20.010253          20.039350        30.451370
# 25%             39.016173          38.539501        52.587201
# 50%             57.516186          57.318691        59.261317
# 75%             75.811622          76.066733        65.963659
# max             94.969517          94.995011        89.138671
# Missing values: aptitude_score           0
# subject_score            0
# time_management_score    0
# mock_average_score       0
# consistency_score        0
# readiness_score          0
# dtype: int64

# %%
DATA_PATH = DATA_DIR / "preprocessed_data.csv"
df.to_csv(DATA_PATH, index=False)

print("Saved dataset at:", DATA_PATH)
# Out:
# Saved dataset at: E:\OTRAS-PLATFORM\otras-platform\ml-service\data\preprocessed_data.csv
