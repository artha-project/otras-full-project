# %%
import pandas as pd
import numpy as np
from pathlib import Path
import random

BASE_DIR = Path("../").resolve()
DATA_DIR = BASE_DIR / "data"
DATA_DIR.mkdir(exist_ok=True)

print("Data directory:", DATA_DIR)
# Out:
# Data directory: C:\Users\satya\Downloads\otras-platform-main (1)\otras-platform-main\ml-service\data

# %%
FEATURE_COLUMNS = [
    "aptitude_score",
    "subject_score",
    "time_management_score",
    "mock_average_score",
    "consistency_score"
]

TARGET_COLUMN = "readiness_score"

# %%
def generate_student_sample():
    aptitude = random.uniform(30, 95)
    subject = random.uniform(25, 95)
    time_mgmt = random.uniform(20, 95)
    mock_avg = random.uniform(20, 95)
    consistency = random.uniform(20, 95)

    # Deterministic readiness formula (baseline truth)
    readiness = (
        0.25 * aptitude +
        0.25 * subject +
        0.2 * time_mgmt +
        0.2 * mock_avg +
        0.1 * consistency
    )

    return [
        aptitude,
        subject,
        time_mgmt,
        mock_avg,
        consistency,
        readiness
    ]

# %%
data = [generate_student_sample() for _ in range(5000)]

df = pd.DataFrame(
    data,
    columns=FEATURE_COLUMNS + [TARGET_COLUMN]
)

df.head()
# Out:
#    aptitude_score  subject_score  time_management_score  mock_average_score  \
# 0       37.940081      41.826084              74.056551           20.939960
# 1       31.160527      92.090528              20.005224           85.729009
# 2       46.167958      59.318776              50.327489           76.198841
# 3       82.321484      86.430603              64.369165           32.124575
# 4       68.675507      80.346833              59.679411           55.132498
#
#    consistency_score  readiness_score
# 0          29.979053        41.938748
# 1          57.729203        57.732531
# 2          60.580718        57.735021
# 3          27.330692        64.219839
# 4          61.051762        66.323143

# %%
print("Dataset shape:", df.shape)
print(df.describe())
print("Missing values:", df.isnull().sum())
# Out:
# Dataset shape: (5000, 6)
#        aptitude_score  subject_score  time_management_score  \
# count     5000.000000    5000.000000            5000.000000
# mean        62.406402      59.902113              57.365581
# std         18.820938      20.036978              21.765166
# min         30.003102      25.005912              20.000832
# 25%         46.264405      42.600828              38.453909
# 50%         62.393477      59.958698              57.665659
# 75%         78.818864      77.057300              75.964745
# max         94.990936      94.959397              94.995060
#
#        mock_average_score  consistency_score  readiness_score
# count         5000.000000        5000.000000      5000.000000
# mean            57.709903          58.099071        59.402133
# std             21.596813          21.653593         9.431470
# min             20.017293          20.007159        31.175536
# 25%             39.009906          39.312681        52.901853
# 50%             58.142315          58.069106        59.411310
# 75%             76.200320          76.780981        65.894242
# max             94.994157          94.994962        91.724352
# Missing values: aptitude_score           0
# subject_score            0
# time_management_score    0
# mock_average_score       0
# consistency_score        0
# readiness_score          0
# dtype: int64

# %%
DATA_PATH = DATA_DIR / "preprocessed_data.csv"
df.to_csv(DATA_PATH, index=False)

print("Saved dataset at:", DATA_PATH)
# Out:
# Saved dataset at: C:\Users\satya\Downloads\otras-platform-main (1)\otras-platform-main\ml-service\data\preprocessed_data.csv
